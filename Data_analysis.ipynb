# %%
from utils import data_analysis

# %%
data_analysis("digikala_dataset","cleaned_dataset.csv")
# Out:
# Dataset : digikala_dataset
#                                  product_name                category1  \
# 0                      جاکارتی طرح هاوایی کد                مد و پوشاک
# 1                شورت زنانه کد  مجموعه  عددی                مد و پوشاک
# 2  استند لوازم اداری رومیزی مدل  مجموعه  عددی  کتاب، لوازم تحریر و هنر
# 3             تقویم جیبی سال  مدل دوچرخه سوار  کتاب، لوازم تحریر و هنر
# 4                        ماسک تزیینی مدل نوا                مد و پوشاک
#
#         category2               category3
# 0  زنانه و مردانه  اکسسوری زنانه و مردانه
# 1           زنانه              لباس زنانه
# 2     لوازم تحریر             لوازم اداری
# 3     لوازم تحریر                 سالنامه
# 4  زنانه و مردانه  اکسسوری زنانه و مردانه
# Training data
# Contains 529322 examples
# Amount of appearances for category1:
#  * unique values 11
#  * Minimal: محصولات بومی و محلی appears 2136 times
#  * Maximal: کالای دیجیتال appears 165651 times
#  * in average 48120.18 times.
#
# ...
